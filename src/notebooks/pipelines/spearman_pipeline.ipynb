# %%
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential
from pipeline_utils import (
    COMPUTE, CONCURRENT_TRIALS, DELAY_EVALUATION, EVALUATION_INTERVAL, GOAL, METRIC, SAMPLING_ALGORITHM, TIMEOUT, TIMEOUT_PLUS, TOTAL_TRIALS, #SWEEP
    SUBSCRIPTION, RESOURCE_GROUP, WS_NAME,  #AUTHENTICATE
    GBC_PATH, NBC_PATH, RFC_PATH, SVC_PATH, XGB_PATH, MULT_NBC_PATH,    #COMPONENTS PATHS
    SPEARMAN_PATH,    #FEAT SEL PATHS
    PREP_DATA_PATH,  #PREP DATA PATH
    GBC_BY_SPEARMAN, NBC_BY_SPEARMAN, RFC_BY_SPEARMAN, SVC_BY_SPEARMAN, XGB_BY_SPEARMAN, MULT_NBC_BY_SPEARMAN,   #PIPELINES
    SPEARMAN,   #FEAT SEL
    N_FEATURES, TRAIN_DATA, TEST_DATA, DATA_VERSION, #PIPELINE VALUES
    get_experiment_names,   #FUNCTIONS
)

# authenticate
credential = DefaultAzureCredential()

# Get a handle to the workspace
ml_client = MLClient(
    credential=credential,
    subscription_id=SUBSCRIPTION,
    resource_group_name=RESOURCE_GROUP,
    workspace_name=WS_NAME,
)

# %%
data_to_train = ml_client.data.get(name=TRAIN_DATA.split('.')[0], version=DATA_VERSION)
print(f"Data to train asset URI: {data_to_train.path} - name: {TRAIN_DATA.split('.')[0]}")

data_to_test = ml_client.data.get(name=TEST_DATA.split('.')[0], version=DATA_VERSION)
print(f"Data to test asset URI: {data_to_test.path} - name: {TEST_DATA.split('.')[0]}")
# Out:
# Data to train asset URI: azureml://subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments/datastores/workspaceblobstore/paths/LocalUpload/3cfdebd258ea2db7363c55bb841ca887/vrex_encoded_tf_idf_2008_2009_2010_2011_2012_2013_2014_2015_2016_2017.csv - name: vrex_encoded_tf_idf_2008_2009_2010_2011_2012_2013_2014_2015_2016_2017
# Data to test asset URI: azureml://subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments/datastores/workspaceblobstore/paths/LocalUpload/3992df39ce41e34367e629d6656f4e9f/vrex_encoded_tf_idf_2018_2019_2020_2021.csv - name: vrex_encoded_tf_idf_2018_2019_2020_2021

# %%
# importing the Component Package
from azure.ai.ml import load_component

data_prep_component = load_component(source=PREP_DATA_PATH)
data_prep_component = ml_client.create_or_update(data_prep_component)

feat_sel_component = load_component(source=SPEARMAN_PATH)
feat_sel_component = ml_client.create_or_update(feat_sel_component)

train_gbc = load_component(source=GBC_PATH)
train_gbc = ml_client.create_or_update(train_gbc)

train_nbc = load_component(source=NBC_PATH)
train_nbc = ml_client.create_or_update(train_nbc)

train_rfc = load_component(source=RFC_PATH)
train_rfc = ml_client.create_or_update(train_rfc)

train_svc = load_component(source=SVC_PATH)
train_svc = ml_client.create_or_update(train_svc)

train_xgb = load_component(source=XGB_PATH)
train_xgb = ml_client.create_or_update(train_xgb)

mult_nbc_train = load_component(source=MULT_NBC_PATH)
mult_nbc_train = ml_client.create_or_update(mult_nbc_train)
# Out:
# Uploading preparation (0.01 MBs): 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5796/5796 [00:00<00:00, 113184.34it/s]
#
#
# Uploading feature_selection (0.01 MBs): 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14061/14061 [00:00<00:00, 295940.01it/s]
#
#
# Uploading train (0.02 MBs): 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20553/20553 [00:00<00:00, 354501.43it/s]

# %%
# the dsl decorator tells the sdk that we are defining an Azure Machine Learning pipeline
from azure.ai.ml import dsl, Input, Output
from azure.ai.ml.sweep import Choice, Uniform, MedianStoppingPolicy

# %%
@dsl.pipeline(
    name=GBC_BY_SPEARMAN,
    compute=COMPUTE,
    description="E2E data_perp-train pipeline",
)
def train_gbc_pipeline(
    data_to_train,
    data_to_test,
    feature_quantity,
    flag_remove_null_values,
    flag_remove_values_by_percentage,
    percentage_to_remove_column,
):

    data_prep_job = data_prep_component(
        data_to_train=data_to_train,
        data_to_test=data_to_test,
        flag_remove_null_values=flag_remove_null_values,
        flag_remove_values_by_percentage=flag_remove_values_by_percentage,
        percentage_to_remove_column=percentage_to_remove_column,
    )

    feat_sel_job = feat_sel_component(
        train_data=data_prep_job.outputs.train_data,
        test_data=data_prep_job.outputs.test_data,
        feature_quantity=feature_quantity,
    )

    train_gbc_job = train_gbc(
        train_data=feat_sel_job.outputs.train_data_feat_sel,  
        test_data=feat_sel_job.outputs.test_data_feat_sel,  
        n_estimators_to_gbc=Choice(values=[50, 100, 200]),
        learning_rate_to_gbc=Uniform(min_value=0.01, max_value=0.3),
    )

    sweep_step_to_gbc = train_gbc_job.sweep(
        compute=COMPUTE,
        sampling_algorithm=SAMPLING_ALGORITHM,
        primary_metric=METRIC,
        goal=GOAL,
    )

    sweep_step_to_gbc.set_limits(max_total_trials=2*TOTAL_TRIALS, max_concurrent_trials=CONCURRENT_TRIALS, timeout=TIMEOUT)

    sweep_step_to_gbc.early_termination = MedianStoppingPolicy(delay_evaluation=DELAY_EVALUATION, evaluation_interval=EVALUATION_INTERVAL)

# %%
@dsl.pipeline(
    name=NBC_BY_SPEARMAN,
    compute=COMPUTE,
    description="E2E data_perp-train pipeline",
)
def train_nbc_pipeline(
    data_to_train,
    data_to_test,
    feature_quantity,
    flag_remove_null_values,
    flag_remove_values_by_percentage,
    percentage_to_remove_column,
):

    data_prep_job = data_prep_component(
        data_to_train=data_to_train,
        data_to_test=data_to_test,
        flag_remove_null_values=flag_remove_null_values,
        flag_remove_values_by_percentage=flag_remove_values_by_percentage,
        percentage_to_remove_column=percentage_to_remove_column,
    )

    feat_sel_job = feat_sel_component(
        train_data=data_prep_job.outputs.train_data,
        test_data=data_prep_job.outputs.test_data,
        feature_quantity=feature_quantity,
    )

    train_nbc_job = train_nbc(
        train_data=feat_sel_job.outputs.train_data_feat_sel,  
        test_data=feat_sel_job.outputs.test_data_feat_sel,  
    )

# %%
@dsl.pipeline(
    name=RFC_BY_SPEARMAN,
    compute=COMPUTE,
    description="E2E data_perp-train pipeline",
)
def train_rfc_pipeline(
    data_to_train,
    data_to_test,
    feature_quantity,
    flag_remove_null_values,
    flag_remove_values_by_percentage,
    percentage_to_remove_column,
):

    data_prep_job = data_prep_component(
        data_to_train=data_to_train,
        data_to_test=data_to_test,
        flag_remove_null_values=flag_remove_null_values,
        flag_remove_values_by_percentage=flag_remove_values_by_percentage,
        percentage_to_remove_column=percentage_to_remove_column,
    )

    feat_sel_job = feat_sel_component(
        train_data=data_prep_job.outputs.train_data,
        test_data=data_prep_job.outputs.test_data,
        feature_quantity=feature_quantity,
    )

    train_rfc_job = train_rfc(
        train_data=feat_sel_job.outputs.train_data_feat_sel,  
        test_data=feat_sel_job.outputs.test_data_feat_sel, 
        n_estimators_to_rfc=Choice(values=[50, 100, 200]),
    )

    sweep_step_to_rfc = train_rfc_job.sweep(
        compute=COMPUTE,
        sampling_algorithm=SAMPLING_ALGORITHM,
        primary_metric=METRIC,
        goal=GOAL,
    )

    sweep_step_to_rfc.set_limits(max_total_trials=TOTAL_TRIALS, max_concurrent_trials=CONCURRENT_TRIALS, timeout=TIMEOUT)
    sweep_step_to_rfc.early_termination = MedianStoppingPolicy(delay_evaluation=DELAY_EVALUATION, evaluation_interval=EVALUATION_INTERVAL)

# %%
@dsl.pipeline(
    name=SVC_BY_SPEARMAN,
    compute=COMPUTE,
    description="E2E data_perp-train pipeline",
)
def train_svc_pipeline(
    data_to_train,
    data_to_test,
    feature_quantity,
    flag_remove_null_values,
    flag_remove_values_by_percentage,
    percentage_to_remove_column,
):

    data_prep_job = data_prep_component(
        data_to_train=data_to_train,
        data_to_test=data_to_test,
        flag_remove_null_values=flag_remove_null_values,
        flag_remove_values_by_percentage=flag_remove_values_by_percentage,
        percentage_to_remove_column=percentage_to_remove_column,
    )

    feat_sel_job = feat_sel_component(
        train_data=data_prep_job.outputs.train_data,
        test_data=data_prep_job.outputs.test_data,
        feature_quantity=feature_quantity,
    )

    train_svc_job = train_svc(
        train_data=feat_sel_job.outputs.train_data_feat_sel,  
        test_data=feat_sel_job.outputs.test_data_feat_sel,   
        kernel_to_svc=Choice(values=["linear", "rbf", "poly", "sigmoid","precomputed"]),
        gamma_to_svc=Choice(values=["scale", "auto"]),
    )

    sweep_step_to_svc = train_svc_job.sweep(
        compute=COMPUTE,
        sampling_algorithm=SAMPLING_ALGORITHM,
        primary_metric=METRIC,
        goal=GOAL,
    )

    sweep_step_to_svc.set_limits(max_total_trials=4*TOTAL_TRIALS, max_concurrent_trials=CONCURRENT_TRIALS, timeout=2*TIMEOUT_PLUS)
    sweep_step_to_svc.early_termination = MedianStoppingPolicy(delay_evaluation=DELAY_EVALUATION, evaluation_interval=EVALUATION_INTERVAL)

# %%
@dsl.pipeline(
    name=XGB_BY_SPEARMAN,
    compute=COMPUTE,
    description="E2E data_perp-train pipeline",
)
def train_xgb_pipeline(
    data_to_train,
    data_to_test,
    feature_quantity,
    flag_remove_null_values,
    flag_remove_values_by_percentage,
    percentage_to_remove_column,
):

    data_prep_job = data_prep_component(
        data_to_train=data_to_train,
        data_to_test=data_to_test,
        flag_remove_null_values=flag_remove_null_values,
        flag_remove_values_by_percentage=flag_remove_values_by_percentage,
        percentage_to_remove_column=percentage_to_remove_column,
    )

    feat_sel_job = feat_sel_component(
        train_data=data_prep_job.outputs.train_data,
        test_data=data_prep_job.outputs.test_data,
        feature_quantity=feature_quantity,
    )

    train_xgb_job = train_xgb(
        train_data=feat_sel_job.outputs.train_data_feat_sel,  
        test_data=feat_sel_job.outputs.test_data_feat_sel,   
        n_estimators_to_xgb=Choice(values=[100, 500, 1000]),
        learning_rate_to_xgb=Uniform(min_value=0.01, max_value=0.3),
    )

    sweep_step_to_xgb = train_xgb_job.sweep(
        compute=COMPUTE,
        sampling_algorithm=SAMPLING_ALGORITHM,
        primary_metric=METRIC,
        goal=GOAL,
    )

    sweep_step_to_xgb.set_limits(max_total_trials=2*TOTAL_TRIALS, max_concurrent_trials=CONCURRENT_TRIALS, timeout=TIMEOUT_PLUS)
    sweep_step_to_xgb.early_termination = MedianStoppingPolicy(delay_evaluation=DELAY_EVALUATION, evaluation_interval=EVALUATION_INTERVAL)

# %%
@dsl.pipeline(
    name=MULT_NBC_BY_SPEARMAN,
    compute=COMPUTE,
    description="E2E data_perp-train pipeline",
)
def train_mult_nbc_pipeline(
    data_to_train,
    data_to_test,
    feature_quantity,
    flag_remove_null_values,
    flag_remove_values_by_percentage,
    percentage_to_remove_column,
):

    data_prep_job = data_prep_component(
        data_to_train=data_to_train,
        data_to_test=data_to_test,
        flag_remove_null_values=flag_remove_null_values,
        flag_remove_values_by_percentage=flag_remove_values_by_percentage,
        percentage_to_remove_column=percentage_to_remove_column,
    )

    feat_sel_job = feat_sel_component(
        train_data=data_prep_job.outputs.train_data,
        test_data=data_prep_job.outputs.test_data,
        feature_quantity=feature_quantity,
    )

    mult_nbc_train_job = mult_nbc_train(
        train_data=feat_sel_job.outputs.train_data_feat_sel,  
        test_data=feat_sel_job.outputs.test_data_feat_sel,  
        alpha=Choice(values=[0.01, 0.1, 0.5, 1.0, 2, 5]),
        fit_prior=Choice(values=[True, False]),
    )

    sweep_step_to_mult_nbc = mult_nbc_train_job.sweep(
        compute=COMPUTE,
        sampling_algorithm=SAMPLING_ALGORITHM,
        primary_metric=METRIC,
        goal=GOAL,
    )

    sweep_step_to_mult_nbc.set_limits(max_total_trials=2*TOTAL_TRIALS, max_concurrent_trials=CONCURRENT_TRIALS, timeout=TIMEOUT_PLUS)

    sweep_step_to_mult_nbc.early_termination = MedianStoppingPolicy(delay_evaluation=DELAY_EVALUATION, evaluation_interval=EVALUATION_INTERVAL)

# %%
pipelines = []

for n_feature in N_FEATURES:
    pipelines.append(train_mult_nbc_pipeline(
        data_to_train=Input(type="uri_file", path=data_to_train.path),
        data_to_test=Input(type="uri_file", path=data_to_test.path),
        feature_quantity=n_feature,
        flag_remove_null_values=False,
        flag_remove_values_by_percentage=False,
        percentage_to_remove_column=0,
    ))

    pipelines.append(train_nbc_pipeline(
        data_to_train=Input(type="uri_file", path=data_to_train.path),
        data_to_test=Input(type="uri_file", path=data_to_test.path),
        feature_quantity=n_feature,
        flag_remove_null_values=False,
        flag_remove_values_by_percentage=False,
        percentage_to_remove_column=0,
    ))

    pipelines.append(train_gbc_pipeline(
        data_to_train=Input(type="uri_file", path=data_to_train.path),
        data_to_test=Input(type="uri_file", path=data_to_test.path),
        feature_quantity=n_feature,
        flag_remove_null_values=False,
        flag_remove_values_by_percentage=False,
        percentage_to_remove_column=0,
    ))

    pipelines.append(train_rfc_pipeline(
        data_to_train=Input(type="uri_file", path=data_to_train.path),
        data_to_test=Input(type="uri_file", path=data_to_test.path),
        feature_quantity=n_feature,
        flag_remove_null_values=False,
        flag_remove_values_by_percentage=False,
        percentage_to_remove_column=0,
    ))
    
    pipelines.append(train_svc_pipeline(
        data_to_train=Input(type="uri_file", path=data_to_train.path),
        data_to_test=Input(type="uri_file", path=data_to_test.path),
        feature_quantity=n_feature,
        flag_remove_null_values=False,
        flag_remove_values_by_percentage=False,
        percentage_to_remove_column=0,
    ))

    pipelines.append(train_xgb_pipeline(
        data_to_train=Input(type="uri_file", path=data_to_train.path),
        data_to_test=Input(type="uri_file", path=data_to_test.path),
        feature_quantity=n_feature,
        flag_remove_null_values=False,
        flag_remove_values_by_percentage=False,
        percentage_to_remove_column=0,
    ))

# %%
experiment_names = get_experiment_names(SPEARMAN)
for pipeline, experiment_name in zip(pipelines, experiment_names):
    pipeline_job = ml_client.jobs.create_or_update(
        pipeline,
        experiment_name=experiment_name,
    )
    ml_client.jobs.stream(pipeline_job.name)
# Out:
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# spearman_MultGaussianNB_N_FEAT_399_DATE_2024_07_09_03_03_09
# spearman_GaussianNB_N_FEAT_399_DATE_2024_07_09_03_03_09
# spearman_GradientBoostingClassifier_N_FEAT_399_DATE_2024_07_09_03_03_09
# spearman_RandomForestClassifier_N_FEAT_399_DATE_2024_07_09_03_03_09
# spearman_SVC_N_FEAT_399_DATE_2024_07_09_03_03_09
# spearman_XGBoost_N_FEAT_399_DATE_2024_07_09_03_03_09
# spearman_MultGaussianNB_N_FEAT_300_DATE_2024_07_09_03_03_09
# spearman_GaussianNB_N_FEAT_300_DATE_2024_07_09_03_03_09
# spearman_GradientBoostingClassifier_N_FEAT_300_DATE_2024_07_09_03_03_09
# spearman_RandomForestClassifier_N_FEAT_300_DATE_2024_07_09_03_03_09
# spearman_SVC_N_FEAT_300_DATE_2024_07_09_03_03_09
# spearman_XGBoost_N_FEAT_300_DATE_2024_07_09_03_03_09
# spearman_MultGaussianNB_N_FEAT_200_DATE_2024_07_09_03_03_09
# spearman_GaussianNB_N_FEAT_200_DATE_2024_07_09_03_03_09
# spearman_GradientBoostingClassifier_N_FEAT_200_DATE_2024_07_09_03_03_09
# spearman_RandomForestClassifier_N_FEAT_200_DATE_2024_07_09_03_03_09
# spearman_SVC_N_FEAT_200_DATE_2024_07_09_03_03_09
# spearman_XGBoost_N_FEAT_200_DATE_2024_07_09_03_03_09
# spearman_MultGaussianNB_N_FEAT_150_DATE_2024_07_09_03_03_09
# spearman_GaussianNB_N_FEAT_150_DATE_2024_07_09_03_03_09
# spearman_GradientBoostingClassifier_N_FEAT_150_DATE_2024_07_09_03_03_09
# spearman_RandomForestClassifier_N_FEAT_150_DATE_2024_07_09_03_03_09
# spearman_SVC_N_FEAT_150_DATE_2024_07_09_03_03_09
# spearman_XGBoost_N_FEAT_150_DATE_2024_07_09_03_03_09
# spearman_MultGaussianNB_N_FEAT_100_DATE_2024_07_09_03_03_09
# spearman_GaussianNB_N_FEAT_100_DATE_2024_07_09_03_03_09
# spearman_GradientBoostingClassifier_N_FEAT_100_DATE_2024_07_09_03_03_09
# spearman_RandomForestClassifier_N_FEAT_100_DATE_2024_07_09_03_03_09
# spearman_SVC_N_FEAT_100_DATE_2024_07_09_03_03_09
# spearman_XGBoost_N_FEAT_100_DATE_2024_07_09_03_03_09
# spearman_MultGaussianNB_N_FEAT_75_DATE_2024_07_09_03_03_09
# spearman_GaussianNB_N_FEAT_75_DATE_2024_07_09_03_03_09
# spearman_GradientBoostingClassifier_N_FEAT_75_DATE_2024_07_09_03_03_09
# spearman_RandomForestClassifier_N_FEAT_75_DATE_2024_07_09_03_03_09
# spearman_SVC_N_FEAT_75_DATE_2024_07_09_03_03_09
# spearman_XGBoost_N_FEAT_75_DATE_2024_07_09_03_03_09
# spearman_MultGaussianNB_N_FEAT_50_DATE_2024_07_09_03_03_09
# spearman_GaussianNB_N_FEAT_50_DATE_2024_07_09_03_03_09
# spearman_GradientBoostingClassifier_N_FEAT_50_DATE_2024_07_09_03_03_09
# spearman_RandomForestClassifier_N_FEAT_50_DATE_2024_07_09_03_03_09
# spearman_SVC_N_FEAT_50_DATE_2024_07_09_03_03_09
# spearman_XGBoost_N_FEAT_50_DATE_2024_07_09_03_03_09
# spearman_MultGaussianNB_N_FEAT_10_DATE_2024_07_09_03_03_09
# spearman_GaussianNB_N_FEAT_10_DATE_2024_07_09_03_03_09
# spearman_GradientBoostingClassifier_N_FEAT_10_DATE_2024_07_09_03_03_09
# spearman_RandomForestClassifier_N_FEAT_10_DATE_2024_07_09_03_03_09
# spearman_SVC_N_FEAT_10_DATE_2024_07_09_03_03_09
# spearman_XGBoost_N_FEAT_10_DATE_2024_07_09_03_03_09
# spearman_MultGaussianNB_N_FEAT_5_DATE_2024_07_09_03_03_09
# spearman_GaussianNB_N_FEAT_5_DATE_2024_07_09_03_03_09
# spearman_GradientBoostingClassifier_N_FEAT_5_DATE_2024_07_09_03_03_09
# spearman_RandomForestClassifier_N_FEAT_5_DATE_2024_07_09_03_03_09
# spearman_SVC_N_FEAT_5_DATE_2024_07_09_03_03_09
# spearman_XGBoost_N_FEAT_5_DATE_2024_07_09_03_03_09
# RunId: khaki_seed_cpdr7hvxd9
# Web View: https://ml.azure.com/runs/khaki_seed_cpdr7hvxd9?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 03:03:17Z] Submitting 1 runs, first five are: 7c9d22fb:4094af02-683c-459b-aa8d-b59daa76c0c2
# [2024-07-09 03:13:16Z] Completing processing run id 4094af02-683c-459b-aa8d-b59daa76c0c2.
# [2024-07-09 03:13:16Z] Submitting 1 runs, first five are: 0985da58:45b8821e-5b56-4788-80a4-8a3d9a4e614e
# [2024-07-09 03:14:35Z] Completing processing run id 45b8821e-5b56-4788-80a4-8a3d9a4e614e.
# [2024-07-09 03:14:36Z] Submitting 1 runs, first five are: 3326d5a5:61a7d344-4266-49ca-a5e8-f2b7f5cee1aa
# [2024-07-09 03:21:24Z] Completing processing run id 61a7d344-4266-49ca-a5e8-f2b7f5cee1aa.
#
# Execution Summary
# =================
# RunId: khaki_seed_cpdr7hvxd9
# Web View: https://ml.azure.com/runs/khaki_seed_cpdr7hvxd9?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: lucid_vulture_kznd97s2w1
# Web View: https://ml.azure.com/runs/lucid_vulture_kznd97s2w1?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 03:21:35Z] Completing processing run id 7df1e7d0-3076-4a14-abb2-a0c5f33c162e.
# [2024-07-09 03:21:36Z] Completing processing run id 0991f619-d2fc-4293-acbf-83853153248b.
# [2024-07-09 03:21:37Z] Submitting 1 runs, first five are: a60e457d:5785c065-a4bd-4f26-b979-9be5190eac65
# [2024-07-09 03:22:42Z] Completing processing run id 5785c065-a4bd-4f26-b979-9be5190eac65.
#
# Execution Summary
# =================
# RunId: lucid_vulture_kznd97s2w1
# Web View: https://ml.azure.com/runs/lucid_vulture_kznd97s2w1?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: good_pear_2hxq1hd4v4
# Web View: https://ml.azure.com/runs/good_pear_2hxq1hd4v4?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 03:22:59Z] Completing processing run id 266e604b-4f2b-437e-ac9d-3afdec85e979.
# [2024-07-09 03:23:00Z] Completing processing run id 085baf3d-bfa2-4508-960c-004ebb6cd936.
# [2024-07-09 03:23:01Z] Submitting 1 runs, first five are: 41ab6dd7:53c92375-57e3-400c-b512-427516164d13
# [2024-07-09 04:09:54Z] Completing processing run id 53c92375-57e3-400c-b512-427516164d13.
#
# Execution Summary
# =================
# RunId: good_pear_2hxq1hd4v4
# Web View: https://ml.azure.com/runs/good_pear_2hxq1hd4v4?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: joyful_hamster_1b9ycl4mg3
# Web View: https://ml.azure.com/runs/joyful_hamster_1b9ycl4mg3?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 04:10:21Z] Completing processing run id e5cfb10f-c61a-45fc-86ac-f10348a9dc6f.
# [2024-07-09 04:10:22Z] Completing processing run id a0c1780a-f923-466e-ab61-2eba145496b4.
# [2024-07-09 04:10:23Z] Submitting 1 runs, first five are: 5256c52f:d2e8fb96-7d21-4cc9-848c-998866681474
# [2024-07-09 04:19:09Z] Completing processing run id d2e8fb96-7d21-4cc9-848c-998866681474.
#
# Execution Summary
# =================
# RunId: joyful_hamster_1b9ycl4mg3
# Web View: https://ml.azure.com/runs/joyful_hamster_1b9ycl4mg3?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: tough_berry_0kfbs801hl
# Web View: https://ml.azure.com/runs/tough_berry_0kfbs801hl?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 04:19:39Z] Completing processing run id 0df0629e-9d56-4246-bf9a-acb39e0e579c.
# [2024-07-09 04:19:40Z] Completing processing run id cf15024c-7cff-40de-8b2b-5c20dd743da4.
# [2024-07-09 04:19:41Z] Submitting 1 runs, first five are: 6d9600c8:a4160e92-63fd-4088-ad06-a91d59e38523
# [2024-07-09 12:21:43Z] Completing processing run id a4160e92-63fd-4088-ad06-a91d59e38523.
#
# Execution Summary
# =================
# RunId: tough_berry_0kfbs801hl
# Web View: https://ml.azure.com/runs/tough_berry_0kfbs801hl?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: jolly_boat_rcssqr979s
# Web View: https://ml.azure.com/runs/jolly_boat_rcssqr979s?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 12:22:30Z] Completing processing run id c936abaa-8b22-4ebc-8d58-fc113c5754b5.
# [2024-07-09 12:22:31Z] Completing processing run id 207ff4b7-b78e-46df-bfee-ffc2e16227be.
# [2024-07-09 12:22:32Z] Submitting 1 runs, first five are: eb24bfed:eb43b189-ef54-4c8c-ada6-f286b4cd5b72
# [2024-07-09 12:45:55Z] Completing processing run id eb43b189-ef54-4c8c-ada6-f286b4cd5b72.
#
# Execution Summary
# =================
# RunId: jolly_boat_rcssqr979s
# Web View: https://ml.azure.com/runs/jolly_boat_rcssqr979s?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: wheat_pumpkin_glgyj8kfkl
# Web View: https://ml.azure.com/runs/wheat_pumpkin_glgyj8kfkl?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 12:46:48Z] Completing processing run id 95ac7241-09c1-4d06-9a0f-2f34923604c7.
# [2024-07-09 12:46:49Z] Submitting 1 runs, first five are: 885847f5:3ee50f13-2668-4b56-85ec-dd6d5194e8ea
# [2024-07-09 12:48:31Z] Completing processing run id 3ee50f13-2668-4b56-85ec-dd6d5194e8ea.
# [2024-07-09 12:48:31Z] Submitting 1 runs, first five are: 9b0dbe32:063c8e00-09c7-4778-8947-70575b860115
# [2024-07-09 12:53:09Z] Completing processing run id 063c8e00-09c7-4778-8947-70575b860115.
#
# Execution Summary
# =================
# RunId: wheat_pumpkin_glgyj8kfkl
# Web View: https://ml.azure.com/runs/wheat_pumpkin_glgyj8kfkl?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: shy_sponge_3rc48rpwx2
# Web View: https://ml.azure.com/runs/shy_sponge_3rc48rpwx2?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 12:54:08Z] Completing processing run id 6bd79443-1a56-4db5-9c76-8d86b952650b.
# [2024-07-09 12:54:09Z] Completing processing run id 723ff7de-1746-47d1-a618-dc9a614d3e10.
# [2024-07-09 12:54:10Z] Submitting 1 runs, first five are: a96a5497:07f6b91a-d232-463c-8838-e70e9ae0821d
# [2024-07-09 12:59:21Z] Completing processing run id 07f6b91a-d232-463c-8838-e70e9ae0821d.
#
# Execution Summary
# =================
# RunId: shy_sponge_3rc48rpwx2
# Web View: https://ml.azure.com/runs/shy_sponge_3rc48rpwx2?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: quirky_truck_290h2113fn
# Web View: https://ml.azure.com/runs/quirky_truck_290h2113fn?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 12:59:32Z] Completing processing run id 7b2a195e-9520-43c1-b69c-7b41d4b90551.
# [2024-07-09 12:59:33Z] Completing processing run id babe89b1-d89e-454f-b05e-ae171d1e3669.
# [2024-07-09 12:59:34Z] Submitting 1 runs, first five are: da7567e9:06e72be8-5ee1-47e5-9eae-def393fedf5d
# [2024-07-09 13:32:28Z] Completing processing run id 06e72be8-5ee1-47e5-9eae-def393fedf5d.
#
# Execution Summary
# =================
# RunId: quirky_truck_290h2113fn
# Web View: https://ml.azure.com/runs/quirky_truck_290h2113fn?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: loyal_bird_kvqhm55mdx
# Web View: https://ml.azure.com/runs/loyal_bird_kvqhm55mdx?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 13:32:52Z] Completing processing run id 4015d0bc-9cc9-4f7a-a242-8e16d4a8216f.
# [2024-07-09 13:32:53Z] Completing processing run id 5c4f4c0e-686a-4e14-89e8-05a48f7f7b97.
# [2024-07-09 13:32:54Z] Submitting 1 runs, first five are: b2aa3ac6:2ea8e2ef-11fd-4cc8-a449-7c1cdd60b3fd
# [2024-07-09 13:37:33Z] Completing processing run id 2ea8e2ef-11fd-4cc8-a449-7c1cdd60b3fd.
#
# Execution Summary
# =================
# RunId: loyal_bird_kvqhm55mdx
# Web View: https://ml.azure.com/runs/loyal_bird_kvqhm55mdx?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: lucid_yuca_q8jwcx1gdh
# Web View: https://ml.azure.com/runs/lucid_yuca_q8jwcx1gdh?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 13:38:20Z] Completing processing run id ec592c96-c2e2-4868-81e2-e7630fc3f987.
# [2024-07-09 13:38:21Z] Completing processing run id 050013ce-33dd-4df8-ac55-a0e868907f27.
# [2024-07-09 13:38:22Z] Submitting 1 runs, first five are: d3cc07b1:2f13164c-d7ac-4026-a434-41a2d84c0a1f
# [2024-07-09 17:29:37Z] Completing processing run id 2f13164c-d7ac-4026-a434-41a2d84c0a1f.
#
# Execution Summary
# =================
# RunId: lucid_yuca_q8jwcx1gdh
# Web View: https://ml.azure.com/runs/lucid_yuca_q8jwcx1gdh?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: sweet_guitar_cgtm3sn50h
# Web View: https://ml.azure.com/runs/sweet_guitar_cgtm3sn50h?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 17:30:23Z] Completing processing run id 81c46284-e528-4ac0-b2a2-8ed506c0e52c.
# [2024-07-09 17:30:24Z] Completing processing run id 45c25b62-4dc6-4780-9dd9-fcbba90e3ff9.
# [2024-07-09 17:30:26Z] Submitting 1 runs, first five are: a24555ec:da36d449-8c55-4cda-9150-39bf248d0f2b
# [2024-07-09 17:50:57Z] Completing processing run id da36d449-8c55-4cda-9150-39bf248d0f2b.
#
# Execution Summary
# =================
# RunId: sweet_guitar_cgtm3sn50h
# Web View: https://ml.azure.com/runs/sweet_guitar_cgtm3sn50h?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: placid_garlic_h6jhtm8fvm
# Web View: https://ml.azure.com/runs/placid_garlic_h6jhtm8fvm?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 17:51:42Z] Completing processing run id 3a3d041b-27f3-4eeb-956f-3cad69b3b793.
# [2024-07-09 17:51:43Z] Submitting 1 runs, first five are: 14052e70:35b81b6c-e6f6-4339-b0dc-6b19809b2a62
# [2024-07-09 17:53:06Z] Completing processing run id 35b81b6c-e6f6-4339-b0dc-6b19809b2a62.
# [2024-07-09 17:53:07Z] Submitting 1 runs, first five are: a39005fb:4ea597a6-4cc1-4734-a695-2639b473216f
# [2024-07-09 17:57:18Z] Completing processing run id 4ea597a6-4cc1-4734-a695-2639b473216f.
#
# Execution Summary
# =================
# RunId: placid_garlic_h6jhtm8fvm
# Web View: https://ml.azure.com/runs/placid_garlic_h6jhtm8fvm?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: lime_soccer_28dxbzs0j7
# Web View: https://ml.azure.com/runs/lime_soccer_28dxbzs0j7?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 17:58:05Z] Completing processing run id 8b315f1a-9b04-4002-beec-5b203188689d.
# [2024-07-09 17:58:05Z] Completing processing run id 1d5df5a2-dfbb-44d0-906d-8c1f8fc9f626.
# [2024-07-09 17:58:08Z] Submitting 1 runs, first five are: 7739c29a:0a18e270-706a-4640-9d0b-a470b7592a76
# [2024-07-09 17:59:15Z] Completing processing run id 0a18e270-706a-4640-9d0b-a470b7592a76.
#
# Execution Summary
# =================
# RunId: lime_soccer_28dxbzs0j7
# Web View: https://ml.azure.com/runs/lime_soccer_28dxbzs0j7?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: eager_planet_zmgpq4y27c
# Web View: https://ml.azure.com/runs/eager_planet_zmgpq4y27c?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 17:59:31Z] Completing processing run id 531c3579-5f84-4f90-857e-0f5a5daffa63.
# [2024-07-09 17:59:33Z] Completing processing run id 2c9a8fca-9860-4fb1-9480-289e01d8ae9f.
# [2024-07-09 17:59:34Z] Submitting 1 runs, first five are: 82c19188:ef383d2b-395c-4d64-8bcf-59b64cafb672
# [2024-07-09 18:43:55Z] Completing processing run id ef383d2b-395c-4d64-8bcf-59b64cafb672.
#
# Execution Summary
# =================
# RunId: eager_planet_zmgpq4y27c
# Web View: https://ml.azure.com/runs/eager_planet_zmgpq4y27c?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: kind_king_tgkpbyry4l
# Web View: https://ml.azure.com/runs/kind_king_tgkpbyry4l?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 18:44:59Z] Completing processing run id 064d8f6e-6e6c-4134-9cc5-7698a7274658.
# [2024-07-09 18:45:00Z] Completing processing run id 5511b995-cef3-4a8d-bf95-3b765bcccf49.
# [2024-07-09 18:45:00Z] Submitting 1 runs, first five are: ee607fc0:13e2e719-90e7-4247-be06-7018877ece31
# [2024-07-09 18:52:16Z] Completing processing run id 13e2e719-90e7-4247-be06-7018877ece31.
#
# Execution Summary
# =================
# RunId: kind_king_tgkpbyry4l
# Web View: https://ml.azure.com/runs/kind_king_tgkpbyry4l?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: yellow_feather_dn0vrtc31q
# Web View: https://ml.azure.com/runs/yellow_feather_dn0vrtc31q?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-09 18:53:19Z] Completing processing run id b081023f-1018-4709-a05e-2774a3ea8c91.
# [2024-07-09 18:53:20Z] Completing processing run id f46396d9-34a5-441b-8dfc-c83c3077f44c.
# [2024-07-09 18:53:21Z] Submitting 1 runs, first five are: 0c965116:6db08e0a-4402-4efb-960c-7459407faed6
# [2024-07-10 01:36:07Z] Completing processing run id 6db08e0a-4402-4efb-960c-7459407faed6.
#
# Execution Summary
# =================
# RunId: yellow_feather_dn0vrtc31q
# Web View: https://ml.azure.com/runs/yellow_feather_dn0vrtc31q?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: heroic_caravan_b7qygnbbvw
# Web View: https://ml.azure.com/runs/heroic_caravan_b7qygnbbvw?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 01:36:51Z] Completing processing run id c7492b82-ef20-40c8-95f3-3e5186b0e67e.
# [2024-07-10 01:36:52Z] Completing processing run id 90ee8557-a5be-4205-ad2f-dd3805a5fdbd.
# [2024-07-10 01:36:53Z] Submitting 1 runs, first five are: 8a6dc149:e93840bb-072c-4229-a08a-1924cf34aa0a
# [2024-07-10 01:58:26Z] Completing processing run id e93840bb-072c-4229-a08a-1924cf34aa0a.
#
# Execution Summary
# =================
# RunId: heroic_caravan_b7qygnbbvw
# Web View: https://ml.azure.com/runs/heroic_caravan_b7qygnbbvw?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: quiet_yacht_sx89nwx05f
# Web View: https://ml.azure.com/runs/quiet_yacht_sx89nwx05f?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 01:58:45Z] Completing processing run id a5f6a6b1-ad4d-46df-8b2a-106e7c43c683.
# [2024-07-10 01:58:46Z] Submitting 1 runs, first five are: 6216a075:ef78d0af-4720-4fe0-b742-8a3e2511bcf9
# [2024-07-10 02:00:09Z] Completing processing run id ef78d0af-4720-4fe0-b742-8a3e2511bcf9.
# [2024-07-10 02:00:09Z] Submitting 1 runs, first five are: 2377a559:8b5bd45e-3fd2-4288-b3b6-5c270999e76a
# [2024-07-10 02:04:49Z] Completing processing run id 8b5bd45e-3fd2-4288-b3b6-5c270999e76a.
#
# Execution Summary
# =================
# RunId: quiet_yacht_sx89nwx05f
# Web View: https://ml.azure.com/runs/quiet_yacht_sx89nwx05f?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: amiable_chaconia_wzzvbndvf7
# Web View: https://ml.azure.com/runs/amiable_chaconia_wzzvbndvf7?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 02:05:09Z] Completing processing run id 3a530fe9-bb7d-4085-83b7-d8bd83d82e43.
# [2024-07-10 02:05:10Z] Completing processing run id eb73bc02-d468-42e4-be80-66bcf60b2bfd.
# [2024-07-10 02:05:11Z] Submitting 1 runs, first five are: 7beb003f:5e7e5545-4179-464c-a595-82f8fc691b72
# [2024-07-10 02:06:07Z] Completing processing run id 5e7e5545-4179-464c-a595-82f8fc691b72.
#
# Execution Summary
# =================
# RunId: amiable_chaconia_wzzvbndvf7
# Web View: https://ml.azure.com/runs/amiable_chaconia_wzzvbndvf7?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: tough_rhythm_b71k4sggnp
# Web View: https://ml.azure.com/runs/tough_rhythm_b71k4sggnp?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 02:06:20Z] Completing processing run id eee365a1-35b2-486d-aa2b-e11a2cadd766.
# [2024-07-10 02:06:21Z] Completing processing run id ec1bd8e3-15fb-4a95-9e3f-9732e40ec8f5.
# [2024-07-10 02:06:22Z] Submitting 1 runs, first five are: a1447266:d3a15b79-a6c3-41d4-9bd1-f9f2215bf64d
# [2024-07-10 02:31:55Z] Completing processing run id d3a15b79-a6c3-41d4-9bd1-f9f2215bf64d.
#
# Execution Summary
# =================
# RunId: tough_rhythm_b71k4sggnp
# Web View: https://ml.azure.com/runs/tough_rhythm_b71k4sggnp?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: dreamy_branch_621hxvvy7p
# Web View: https://ml.azure.com/runs/dreamy_branch_621hxvvy7p?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 02:32:40Z] Completing processing run id 112fcadb-9f74-4f5d-bcc2-47b8590e83e5.
# [2024-07-10 02:32:41Z] Completing processing run id 348d7863-9890-4c85-8ffe-f376e9c67de1.
# [2024-07-10 02:32:42Z] Submitting 1 runs, first five are: a74401ae:e61b29d9-3211-4e3d-a039-fc00f59a2cae
# [2024-07-10 02:35:49Z] Completing processing run id e61b29d9-3211-4e3d-a039-fc00f59a2cae.
#
# Execution Summary
# =================
# RunId: dreamy_branch_621hxvvy7p
# Web View: https://ml.azure.com/runs/dreamy_branch_621hxvvy7p?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: willing_parsnip_p7b0bjx2tl
# Web View: https://ml.azure.com/runs/willing_parsnip_p7b0bjx2tl?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 02:36:05Z] Completing processing run id 7c9cc3b7-7d75-4541-bcb1-47694b12e1b1.
# [2024-07-10 02:36:06Z] Completing processing run id 01671979-9b05-4797-9602-e049557511ee.
# [2024-07-10 02:36:06Z] Submitting 1 runs, first five are: c9bbb7ad:558e0f07-1359-4391-8064-f5aae3471e22
# [2024-07-10 04:26:30Z] Completing processing run id 558e0f07-1359-4391-8064-f5aae3471e22.
#
# Execution Summary
# =================
# RunId: willing_parsnip_p7b0bjx2tl
# Web View: https://ml.azure.com/runs/willing_parsnip_p7b0bjx2tl?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: good_ship_jdwq168sdh
# Web View: https://ml.azure.com/runs/good_ship_jdwq168sdh?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 04:26:43Z] Completing processing run id b60167b4-99ad-4b88-abaf-b50b40db812e.
# [2024-07-10 04:26:43Z] Completing processing run id 0b8e6846-7ec4-42ad-b8f2-3590d73d1fd5.
# [2024-07-10 04:26:44Z] Submitting 1 runs, first five are: d3d1f9b6:adf2134d-255d-4a3d-8e42-c3e39f994453
# [2024-07-10 04:44:39Z] Completing processing run id adf2134d-255d-4a3d-8e42-c3e39f994453.
#
# Execution Summary
# =================
# RunId: good_ship_jdwq168sdh
# Web View: https://ml.azure.com/runs/good_ship_jdwq168sdh?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: upbeat_mango_9sj7fqmv7n
# Web View: https://ml.azure.com/runs/upbeat_mango_9sj7fqmv7n?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 04:45:35Z] Completing processing run id 27b04368-7ece-47f2-890a-fd83454d884c.
# [2024-07-10 04:45:36Z] Submitting 1 runs, first five are: 671bebca:3ead360b-9a12-4e7f-b1cd-f436cade897a
# [2024-07-10 04:46:50Z] Completing processing run id 3ead360b-9a12-4e7f-b1cd-f436cade897a.
# [2024-07-10 04:46:51Z] Submitting 1 runs, first five are: 08ac0b27:d78112a7-8221-42bd-9305-b4e24a1dcc84
# [2024-07-10 04:51:00Z] Completing processing run id d78112a7-8221-42bd-9305-b4e24a1dcc84.
#
# Execution Summary
# =================
# RunId: upbeat_mango_9sj7fqmv7n
# Web View: https://ml.azure.com/runs/upbeat_mango_9sj7fqmv7n?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: sweet_shark_tt9m1qt7dk
# Web View: https://ml.azure.com/runs/sweet_shark_tt9m1qt7dk?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 04:51:57Z] Completing processing run id af8fc2d8-a742-426d-bc19-bb7cddae2809.
# [2024-07-10 04:51:57Z] Completing processing run id 6990e52b-0223-4626-847f-f70ed4bc4b8b.
# [2024-07-10 04:51:58Z] Submitting 1 runs, first five are: e94e8c07:3e573253-e8c1-4943-bf1b-d4837cafbcde
# [2024-07-10 04:57:44Z] Completing processing run id 3e573253-e8c1-4943-bf1b-d4837cafbcde.
#
# Execution Summary
# =================
# RunId: sweet_shark_tt9m1qt7dk
# Web View: https://ml.azure.com/runs/sweet_shark_tt9m1qt7dk?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: lemon_fowl_9ny01y3p8j
# Web View: https://ml.azure.com/runs/lemon_fowl_9ny01y3p8j?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 04:58:19Z] Completing processing run id 9271b57c-fab9-49b6-90c3-2833f3121a01.
# [2024-07-10 04:58:20Z] Completing processing run id e54f66b4-0732-4e22-a9eb-f4876d2d58c0.
# [2024-07-10 04:58:21Z] Submitting 1 runs, first five are: 1666aa0f:75c8ddc7-93ed-40fd-b2bb-26e63f290d7f
# [2024-07-10 05:27:27Z] Completing processing run id 75c8ddc7-93ed-40fd-b2bb-26e63f290d7f.
#
# Execution Summary
# =================
# RunId: lemon_fowl_9ny01y3p8j
# Web View: https://ml.azure.com/runs/lemon_fowl_9ny01y3p8j?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: brave_eye_wsls3kqtm9
# Web View: https://ml.azure.com/runs/brave_eye_wsls3kqtm9?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 05:27:39Z] Completing processing run id d3b7115a-9c04-4f28-9582-f32d27c99d3e.
# [2024-07-10 05:27:40Z] Completing processing run id 896e6f5a-d7c3-4d66-8016-b3a8af674b8f.
# [2024-07-10 05:27:42Z] Submitting 1 runs, first five are: eef85ca8:6b55858e-33f5-4345-a998-af2b9359ad42
# [2024-07-10 05:30:51Z] Completing processing run id 6b55858e-33f5-4345-a998-af2b9359ad42.
#
# Execution Summary
# =================
# RunId: brave_eye_wsls3kqtm9
# Web View: https://ml.azure.com/runs/brave_eye_wsls3kqtm9?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: zen_cheese_mpj6tntlyt
# Web View: https://ml.azure.com/runs/zen_cheese_mpj6tntlyt?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 05:31:04Z] Completing processing run id e377c719-5e8f-47eb-9979-0928c1ded24c.
# [2024-07-10 05:31:05Z] Completing processing run id f3ad01ad-f6ac-42d7-9f65-2d6678dd376b.
# [2024-07-10 05:31:06Z] Submitting 1 runs, first five are: 569a5b99:c3382d91-6e23-4042-b05a-31b9cddd42cd
# [2024-07-10 09:21:51Z] Completing processing run id c3382d91-6e23-4042-b05a-31b9cddd42cd.
#
# Execution Summary
# =================
# RunId: zen_cheese_mpj6tntlyt
# Web View: https://ml.azure.com/runs/zen_cheese_mpj6tntlyt?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: polite_parang_40nyq2zd8f
# Web View: https://ml.azure.com/runs/polite_parang_40nyq2zd8f?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 09:22:01Z] Completing processing run id 0c53676c-42d8-426c-8257-4bee2897e259.
# [2024-07-10 09:22:02Z] Completing processing run id 8217ab7c-3969-4a50-ba91-b7eea3c21ccf.
# [2024-07-10 09:22:03Z] Submitting 1 runs, first five are: cc5c96ba:d7217cc1-1ee9-47bc-bff8-cb29ff5eff43
# [2024-07-10 09:46:25Z] Completing processing run id d7217cc1-1ee9-47bc-bff8-cb29ff5eff43.
#
# Execution Summary
# =================
# RunId: polite_parang_40nyq2zd8f
# Web View: https://ml.azure.com/runs/polite_parang_40nyq2zd8f?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: elated_puppy_zt9lfr47jm
# Web View: https://ml.azure.com/runs/elated_puppy_zt9lfr47jm?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 09:47:19Z] Completing processing run id 697036f3-f486-40f4-9511-fe92ce4eac3c.
# [2024-07-10 09:47:20Z] Submitting 1 runs, first five are: 9b6bc2b8:b756e731-fe8f-46a6-9f29-f19f397d3802
# [2024-07-10 09:48:46Z] Completing processing run id b756e731-fe8f-46a6-9f29-f19f397d3802.
# [2024-07-10 09:48:46Z] Submitting 1 runs, first five are: bc8410a7:91425444-23ff-4645-b9ec-c5e6a09312d0
# [2024-07-10 10:01:09Z] Completing processing run id 91425444-23ff-4645-b9ec-c5e6a09312d0.
#
# Execution Summary
# =================
# RunId: elated_puppy_zt9lfr47jm
# Web View: https://ml.azure.com/runs/elated_puppy_zt9lfr47jm?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: plucky_sugar_x1kmdpkm0m
# Web View: https://ml.azure.com/runs/plucky_sugar_x1kmdpkm0m?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 10:01:37Z] Completing processing run id 28dd6d07-c070-4a88-821b-1be9f96c2c6f.
# [2024-07-10 10:01:38Z] Completing processing run id fda8baf6-c0d9-42b4-a18c-a8f47ff43fba.
# [2024-07-10 10:01:39Z] Submitting 1 runs, first five are: 3b51ae05:16299ab4-d7c7-4e64-86f8-cce7e99a7bb7
# [2024-07-10 10:02:33Z] Completing processing run id 16299ab4-d7c7-4e64-86f8-cce7e99a7bb7.
#
# Execution Summary
# =================
# RunId: plucky_sugar_x1kmdpkm0m
# Web View: https://ml.azure.com/runs/plucky_sugar_x1kmdpkm0m?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: frank_salt_vd3f1p3cbg
# Web View: https://ml.azure.com/runs/frank_salt_vd3f1p3cbg?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 10:02:40Z] Completing processing run id 980d3334-2a29-492d-a9cb-9e7d8eae9ad8.
# [2024-07-10 10:02:41Z] Completing processing run id ed25ccc1-68b9-4624-9e08-94fabc9e34ab.
# [2024-07-10 10:02:41Z] Submitting 1 runs, first five are: d30ca060:5055dd1e-eb40-4407-9335-cc02d94e0eb4
# [2024-07-10 10:48:26Z] Completing processing run id 5055dd1e-eb40-4407-9335-cc02d94e0eb4.
#
# Execution Summary
# =================
# RunId: frank_salt_vd3f1p3cbg
# Web View: https://ml.azure.com/runs/frank_salt_vd3f1p3cbg?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: kind_spoon_01qmqzzcl3
# Web View: https://ml.azure.com/runs/kind_spoon_01qmqzzcl3?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 10:48:38Z] Completing processing run id 07da05c9-4f73-4484-85e5-f437477629aa.
# [2024-07-10 10:48:39Z] Completing processing run id 6af1e72b-c62c-48c1-9c0c-70be8806121e.
# [2024-07-10 10:48:40Z] Submitting 1 runs, first five are: a2b93407:7377eccc-01d3-422c-a322-41b1a99a0823
# [2024-07-10 10:56:00Z] Completing processing run id 7377eccc-01d3-422c-a322-41b1a99a0823.
#
# Execution Summary
# =================
# RunId: kind_spoon_01qmqzzcl3
# Web View: https://ml.azure.com/runs/kind_spoon_01qmqzzcl3?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: orange_forest_n2475gfsl2
# Web View: https://ml.azure.com/runs/orange_forest_n2475gfsl2?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 10:57:00Z] Completing processing run id d0f0b80c-a866-4b7f-8b2e-2d79c70e90c4.
# [2024-07-10 10:57:01Z] Completing processing run id dadfceda-9c81-4a2d-9e7e-9feb382576ad.
# [2024-07-10 10:57:01Z] Submitting 1 runs, first five are: 99996547:f3d2df95-b27b-4fba-a100-2410a4d59fc2
# [2024-07-10 13:26:17Z] Completing processing run id f3d2df95-b27b-4fba-a100-2410a4d59fc2.
#
# Execution Summary
# =================
# RunId: orange_forest_n2475gfsl2
# Web View: https://ml.azure.com/runs/orange_forest_n2475gfsl2?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: heroic_fish_53znx7hskf
# Web View: https://ml.azure.com/runs/heroic_fish_53znx7hskf?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 13:26:39Z] Completing processing run id 50fc1f04-4e77-4385-8bcb-d64ed205676d.
# [2024-07-10 13:26:40Z] Completing processing run id dad7d478-0829-471d-8202-17f21c4d8fe8.
# [2024-07-10 13:26:41Z] Submitting 1 runs, first five are: ce1cf361:e5dea276-125f-4924-85cd-09d7019f5953
# [2024-07-10 13:53:44Z] Completing processing run id e5dea276-125f-4924-85cd-09d7019f5953.
#
# Execution Summary
# =================
# RunId: heroic_fish_53znx7hskf
# Web View: https://ml.azure.com/runs/heroic_fish_53znx7hskf?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: blue_soca_41y0jqsnbv
# Web View: https://ml.azure.com/runs/blue_soca_41y0jqsnbv?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 13:53:56Z] Completing processing run id 84b0ed3c-37f7-4a0d-9152-907ed059872f.
# [2024-07-10 13:54:00Z] Submitting 1 runs, first five are: ed212143:105a19bf-46b0-4277-9c21-444ef79d76c7
# [2024-07-10 13:59:14Z] Completing processing run id 105a19bf-46b0-4277-9c21-444ef79d76c7.
# [2024-07-10 13:59:15Z] Submitting 1 runs, first five are: bc0a2507:4fdd06fc-fa4e-4e62-a6aa-f2440e24b342
# [2024-07-10 14:09:00Z] Completing processing run id 4fdd06fc-fa4e-4e62-a6aa-f2440e24b342.
#
# Execution Summary
# =================
# RunId: blue_soca_41y0jqsnbv
# Web View: https://ml.azure.com/runs/blue_soca_41y0jqsnbv?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: upbeat_chain_ph0lvbk4ds
# Web View: https://ml.azure.com/runs/upbeat_chain_ph0lvbk4ds?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 14:09:11Z] Completing processing run id 2bd62281-7e78-4833-a6dc-e36c8e6526c2.
# [2024-07-10 14:09:12Z] Completing processing run id 0e6fbe4d-f717-4657-aba9-81177dc353be.
# [2024-07-10 14:09:13Z] Submitting 1 runs, first five are: 5aa90599:fafc8998-c732-4b6c-b799-e7b6d671e3aa
# [2024-07-10 14:13:46Z] Completing processing run id fafc8998-c732-4b6c-b799-e7b6d671e3aa.
#
# Execution Summary
# =================
# RunId: upbeat_chain_ph0lvbk4ds
# Web View: https://ml.azure.com/runs/upbeat_chain_ph0lvbk4ds?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: bold_line_b6nnsw8p21
# Web View: https://ml.azure.com/runs/bold_line_b6nnsw8p21?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 14:14:37Z] Completing processing run id 9451b389-2dbd-4a82-88e2-7390dfb3d1ee.
# [2024-07-10 14:14:38Z] Completing processing run id 57c1a79b-349b-4ec9-b174-7fafaf1574d9.
# [2024-07-10 14:14:39Z] Submitting 1 runs, first five are: 1db7b5a0:0b33c0fa-b17a-437d-8f48-f7ce5f348a81
# [2024-07-10 14:54:57Z] Completing processing run id 0b33c0fa-b17a-437d-8f48-f7ce5f348a81.
#
# Execution Summary
# =================
# RunId: bold_line_b6nnsw8p21
# Web View: https://ml.azure.com/runs/bold_line_b6nnsw8p21?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: maroon_owl_s5m4jb80cl
# Web View: https://ml.azure.com/runs/maroon_owl_s5m4jb80cl?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 14:55:58Z] Completing processing run id 060c7eac-c3c5-4344-b135-e80f1dd4c015.
# [2024-07-10 14:55:59Z] Completing processing run id edd962ef-7d66-4e8c-aabd-9cb0a4f5eded.
# [2024-07-10 14:56:00Z] Submitting 1 runs, first five are: b9c5db36:e74276a4-f4ef-4b77-84c4-e90c566e506f
# [2024-07-10 15:02:41Z] Completing processing run id e74276a4-f4ef-4b77-84c4-e90c566e506f.
#
# Execution Summary
# =================
# RunId: maroon_owl_s5m4jb80cl
# Web View: https://ml.azure.com/runs/maroon_owl_s5m4jb80cl?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: lime_sponge_7rz21sm39x
# Web View: https://ml.azure.com/runs/lime_sponge_7rz21sm39x?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 15:03:21Z] Completing processing run id 8a6504f5-4a01-4a0d-b537-4bc8773c5494.
# [2024-07-10 15:03:22Z] Completing processing run id 7ae01ba6-a91b-463c-a1a6-39e7992b96ff.
# [2024-07-10 15:03:23Z] Submitting 1 runs, first five are: f9a21f96:1d5f86a1-620b-492d-af57-16ced46aff7c
# [2024-07-10 16:54:25Z] Completing processing run id 1d5f86a1-620b-492d-af57-16ced46aff7c.
#
# Execution Summary
# =================
# RunId: lime_sponge_7rz21sm39x
# Web View: https://ml.azure.com/runs/lime_sponge_7rz21sm39x?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: clever_bag_zbjgj88ctj
# Web View: https://ml.azure.com/runs/clever_bag_zbjgj88ctj?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 16:54:57Z] Completing processing run id d6ae7c68-e473-4bf5-819b-950fc2a51174.
# [2024-07-10 16:54:58Z] Completing processing run id 74d2facd-67b3-4900-8f0b-431c1c8389c1.
# [2024-07-10 16:54:59Z] Submitting 1 runs, first five are: d023a6f4:adac9ed1-7e2e-4e87-82a2-8960a22e645c
# [2024-07-10 17:33:07Z] Completing processing run id adac9ed1-7e2e-4e87-82a2-8960a22e645c.
#
# Execution Summary
# =================
# RunId: clever_bag_zbjgj88ctj
# Web View: https://ml.azure.com/runs/clever_bag_zbjgj88ctj?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: coral_soccer_3q668gxzs8
# Web View: https://ml.azure.com/runs/coral_soccer_3q668gxzs8?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 17:33:19Z] Completing processing run id 26a9d693-5953-415e-9644-1ff0a034e004.
# [2024-07-10 17:33:21Z] Submitting 1 runs, first five are: ed749e41:4557b611-ce8c-46ac-8a8d-8214167966f8
# [2024-07-10 17:40:36Z] Completing processing run id 4557b611-ce8c-46ac-8a8d-8214167966f8.
# [2024-07-10 17:40:37Z] Submitting 1 runs, first five are: f2ccd7d4:515f156f-4776-4208-bbee-afd23269422f
# [2024-07-10 17:49:22Z] Completing processing run id 515f156f-4776-4208-bbee-afd23269422f.
#
# Execution Summary
# =================
# RunId: coral_soccer_3q668gxzs8
# Web View: https://ml.azure.com/runs/coral_soccer_3q668gxzs8?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: silly_spinach_zdx129qyc3
# Web View: https://ml.azure.com/runs/silly_spinach_zdx129qyc3?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 17:49:34Z] Completing processing run id 7193304a-d85a-4ba7-9aac-42432758e557.
# [2024-07-10 17:49:36Z] Completing processing run id 6963272f-2720-42e8-82e5-1b41bea93ba7.
# [2024-07-10 17:49:36Z] Submitting 1 runs, first five are: 6c247af7:26151658-8a7d-4cbb-9950-36ac28955220
# [2024-07-10 17:55:54Z] Completing processing run id 26151658-8a7d-4cbb-9950-36ac28955220.
#
# Execution Summary
# =================
# RunId: silly_spinach_zdx129qyc3
# Web View: https://ml.azure.com/runs/silly_spinach_zdx129qyc3?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: orange_soursop_yncc9dl933
# Web View: https://ml.azure.com/runs/orange_soursop_yncc9dl933?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 17:56:56Z] Completing processing run id 54779dd4-94f8-458b-b6d4-6958aee1cd21.
# [2024-07-10 17:56:57Z] Completing processing run id 18319337-44dc-416a-81ea-2c104345c492.
# [2024-07-10 17:56:58Z] Submitting 1 runs, first five are: daf7b0a9:382b0d02-1967-461c-943b-8b65a2cb5a20
# [2024-07-10 18:16:59Z] Completing processing run id 382b0d02-1967-461c-943b-8b65a2cb5a20.
#
# Execution Summary
# =================
# RunId: orange_soursop_yncc9dl933
# Web View: https://ml.azure.com/runs/orange_soursop_yncc9dl933?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: lemon_seal_wz4315wl0y
# Web View: https://ml.azure.com/runs/lemon_seal_wz4315wl0y?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 18:17:13Z] Completing processing run id 3350fc1b-3b3c-4c8e-bd0c-4bb56e5a7dbb.
# [2024-07-10 18:17:14Z] Completing processing run id 76d03f9d-057a-497c-ba3a-c4cf235fc8c3.
# [2024-07-10 18:17:15Z] Submitting 1 runs, first five are: dbb70014:8c93bf10-08d5-4909-9b48-00b1fbf4ed7e
# [2024-07-10 18:25:29Z] Completing processing run id 8c93bf10-08d5-4909-9b48-00b1fbf4ed7e.
#
# Execution Summary
# =================
# RunId: lemon_seal_wz4315wl0y
# Web View: https://ml.azure.com/runs/lemon_seal_wz4315wl0y?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: stoic_ant_mpbl2kk0cl
# Web View: https://ml.azure.com/runs/stoic_ant_mpbl2kk0cl?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 18:26:33Z] Completing processing run id 0743fd44-3589-41f9-98f2-f6e33ef0fcea.
# [2024-07-10 18:26:34Z] Completing processing run id 57a48462-77ad-4b6b-97ce-8ad694efac9b.
# [2024-07-10 18:26:36Z] Submitting 1 runs, first five are: 5ad5a90e:670bf62c-5abe-42ec-b683-b7ff96a8e955
# [2024-07-10 19:13:14Z] Completing processing run id 670bf62c-5abe-42ec-b683-b7ff96a8e955.
#
# Execution Summary
# =================
# RunId: stoic_ant_mpbl2kk0cl
# Web View: https://ml.azure.com/runs/stoic_ant_mpbl2kk0cl?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: sad_kite_jn9sn3fw87
# Web View: https://ml.azure.com/runs/sad_kite_jn9sn3fw87?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 19:13:59Z] Completing processing run id c0e1f9f0-afa4-4674-b9f6-37740b19bc0d.
# [2024-07-10 19:14:00Z] Completing processing run id 916483a3-a287-4c54-bb63-7a8b24ab2b0b.
# [2024-07-10 19:14:01Z] Submitting 1 runs, first five are: 0d06c1be:ce311d17-cc3c-4b99-9a28-b6a8a39ae358
# [2024-07-10 19:34:31Z] Completing processing run id ce311d17-cc3c-4b99-9a28-b6a8a39ae358.
#
# Execution Summary
# =================
# RunId: sad_kite_jn9sn3fw87
# Web View: https://ml.azure.com/runs/sad_kite_jn9sn3fw87?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: great_carnival_t3z2y62p9r
# Web View: https://ml.azure.com/runs/great_carnival_t3z2y62p9r?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 19:34:40Z] Completing processing run id dc6dbb98-16c9-4e3d-b573-5e2598fb367e.
# [2024-07-10 19:34:41Z] Submitting 1 runs, first five are: 0d1012c2:abb26588-f2a8-4665-a359-f5490f84a08f
# [2024-07-10 19:35:58Z] Completing processing run id abb26588-f2a8-4665-a359-f5490f84a08f.
# [2024-07-10 19:35:59Z] Submitting 1 runs, first five are: f6534c6d:ee54a748-8eaa-41be-a0d5-3c1b3ed37f13
# [2024-07-10 19:40:08Z] Completing processing run id ee54a748-8eaa-41be-a0d5-3c1b3ed37f13.
#
# Execution Summary
# =================
# RunId: great_carnival_t3z2y62p9r
# Web View: https://ml.azure.com/runs/great_carnival_t3z2y62p9r?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: eager_arch_f823g75hxp
# Web View: https://ml.azure.com/runs/eager_arch_f823g75hxp?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 19:41:02Z] Completing processing run id 4c1d6c7e-c0cb-4c3d-87d9-21aff8ccd412.
# [2024-07-10 19:41:02Z] Completing processing run id 64b5c626-1102-498e-832d-4514e377b2fe.
# [2024-07-10 19:41:03Z] Submitting 1 runs, first five are: b0385f7a:7a1fed38-89ea-42ae-813a-6f0125d584f5
# [2024-07-10 19:46:51Z] Completing processing run id 7a1fed38-89ea-42ae-813a-6f0125d584f5.
#
# Execution Summary
# =================
# RunId: eager_arch_f823g75hxp
# Web View: https://ml.azure.com/runs/eager_arch_f823g75hxp?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: red_nerve_5dq1k8v2z0
# Web View: https://ml.azure.com/runs/red_nerve_5dq1k8v2z0?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 19:47:27Z] Completing processing run id 4a801634-af8c-4b9e-a544-096b11523516.
# [2024-07-10 19:47:28Z] Completing processing run id 5f3ea34a-f777-4ba4-9601-9729e2ac4617.
# [2024-07-10 19:47:29Z] Submitting 1 runs, first five are: 5fd0b4c0:df862018-43b6-4aea-9454-8b889783249a
# [2024-07-10 20:23:02Z] Completing processing run id df862018-43b6-4aea-9454-8b889783249a.
#
# Execution Summary
# =================
# RunId: red_nerve_5dq1k8v2z0
# Web View: https://ml.azure.com/runs/red_nerve_5dq1k8v2z0?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: keen_line_1rmv1pw0rv
# Web View: https://ml.azure.com/runs/keen_line_1rmv1pw0rv?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 20:23:49Z] Completing processing run id 88817670-884c-4ef8-9169-2b480aae6e43.
# [2024-07-10 20:23:50Z] Completing processing run id 0fcdc25a-3192-4e34-97ca-f775b8ca2e57.
# [2024-07-10 20:23:51Z] Submitting 1 runs, first five are: a5b55a2e:bd207dd6-7766-46bb-9c44-8ceee600b6dd
# [2024-07-10 20:25:28Z] Completing processing run id bd207dd6-7766-46bb-9c44-8ceee600b6dd.
#
# Execution Summary
# =================
# RunId: keen_line_1rmv1pw0rv
# Web View: https://ml.azure.com/runs/keen_line_1rmv1pw0rv?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: serene_brain_b4058kct9b
# Web View: https://ml.azure.com/runs/serene_brain_b4058kct9b?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 20:25:37Z] Completing processing run id 365f5782-3380-4088-8b08-d1a03856e986.
# [2024-07-10 20:25:39Z] Completing processing run id f2f32a86-6c6b-48dc-b141-2ff93ca66106.
# [2024-07-10 20:25:39Z] Submitting 1 runs, first five are: a1f9d74c:973c2af1-4a6a-4186-af55-7f0b278ab2ad
# [2024-07-10 20:48:39Z] Completing processing run id 973c2af1-4a6a-4186-af55-7f0b278ab2ad.
#
# Execution Summary
# =================
# RunId: serene_brain_b4058kct9b
# Web View: https://ml.azure.com/runs/serene_brain_b4058kct9b?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# RunId: bright_cloud_pprgncq68t
# Web View: https://ml.azure.com/runs/bright_cloud_pprgncq68t?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
#
# Streaming logs/azureml/executionlogs.txt
# ========================================
#
# [2024-07-10 20:48:52Z] Completing processing run id 623e623b-9b2b-49dd-9624-19438be9e8e1.
# [2024-07-10 20:48:53Z] Completing processing run id 4691b81c-71aa-4ff3-b84e-e8b3aae0093f.
# [2024-07-10 20:48:54Z] Submitting 1 runs, first five are: d8f7af18:60d39014-9c98-429f-9dd0-3ae2a77a410e
# [2024-07-10 21:09:54Z] Completing processing run id 60d39014-9c98-429f-9dd0-3ae2a77a410e.
#
# Execution Summary
# =================
# RunId: bright_cloud_pprgncq68t
# Web View: https://ml.azure.com/runs/bright_cloud_pprgncq68t?wsid=/subscriptions/da6ec459-95c4-4f18-8440-d275df8d38b7/resourcegroups/tcc-exp-rg/workspaces/tcc-experiments
